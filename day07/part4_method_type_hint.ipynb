# %%
# part4_method_type_hint.py
# 함수의 매개변수를 정할 때, 함수를 사용하는 쪽에서 전달하는 값의 타입을
# 미리 정하여서 이에 대한 힌트를 주는 것을 타입 힌트라고 부른다.
# 타입 힌트를 사용하는 이유는 연산을 위해서 적절한 데이터 타입을 전달받기 위함이다.
# 매개변수 뒤에 콜론:과 함께 타입을 작성하면
# 해당 타입으로 전달받는 인자, 인수를 반강제할 수 있다.
# def 함수명(매개:타입, 매개:타입):

# 전달받는 값을 숫자로 제한, 타입 힌트
# def add(num1, num2): # 타입 힌트가 없는 상태에서는
    # 숫자와 문자, 리스트 등 제한없이 전달받을 수 있다.
    # 때문에 함수를 작성한 작성자의 의도와 다른 값이 전달되어
    # 오류가 발생할 수 있다.
    # 이를 방지하고자 타입힌트를 사용한다.
def add(num1:int, num2:int): # 타입힌트를 사용한 경우
    result = None
    result = num1 + num2
    return result

# 함수 헤드 마지막 콜론: 앞에 ->를 작성하고
# 타입을 작성하면 해당 함수의 반환값의 타입 힌트를 작성할 수 있다.
def add(num1:int, num2:int) -> int:
    result: int = num1 + num2 # 변수에 타입 힌트를 작성할 수도 있다.
    return result

# 타입힌트가 중요한 이유는, 리스트 등 이터러블 객체들은
# 각 종류마다 사용할 수 있는 함수가 다르다는 부분에 있다.
# 만약 타입 힌트가 없으면 사용할 수 있는 함수에 대한 자동완성을
# 지원할 수 없게 된다.
def test(vars): # 타입힌트를 적으면
    # 해당 변수에 마침표.를 찍어서 함수를 사용할 때
    # 자동완성으로 내부 함수를 만들 수 있지만
    # 타입힌트가 없으면 아무것도 나오지 않게 된다.
    # print(vars.) # 아무것도 안 나옴
    pass

if __name__ == "__main__":
    # print(add("이", 2))
    print(add(2, 3)) # 빨간 줄이 그어져서 실행자체가 안 되는 건 아니지만
    # 힌트를 주는 것으로 입력하는 쪽에서 문제가 발생할 여지를 줄일 수 있다.
    pass
